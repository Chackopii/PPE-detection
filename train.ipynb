# %%
import torch

# %%
torch.__version__
# Out:
# '2.2.1+cu121'

# %%
# !nvidia-smi
# Out:
# Thu Mar 14 13:21:46 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.76                 Driver Version: 551.76         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650 Ti   WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   58C    P8              3W /   50W |     367MiB /   4096MiB |      9%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

# %%
# %pwd
# Out:
# 'D:\\python\\Opencv\\PPE detection'

# %%
model=YOLO('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
result=model.train(data='data.yaml', epochs=100, batch=3, imgsz=640 )
# Out:
# New https://pypi.org/project/ultralytics/8.1.27 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.9.0 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
model=YOLO('runs/detect/train6/weights/best.pt')
model.info()
# Out:
# YOLOv8n summary: 225 layers, 3012798 parameters, 0 gradients, 8.2 GFLOPs
# (225, 3012798, 0, 8.2038272)

# %%
results = model('OIP (2).jpg', save=True)
# Out:
# image 1/1 D:\python\Opencv\PPE detection\OIP (2).jpg: 640x512 1 Hardhat, 1 NO-Mask, 2 Persons, 63.7ms
# Speed: 0.0ms preprocess, 63.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs\detect\predict6
